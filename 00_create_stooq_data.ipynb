# %% [markdown]
# # Download and store STOOQ data

# %% [markdown]
# This notebook contains information on downloading the STOOQ stock and ETF price data that we use in [Chapter 09](../09_time_series_models) for a pairs trading strategy based on cointegration and [Chapter 11](../11_decision_trees_random_forests) for a long-short strategy using Random Forest return predictions.

# %% [markdown]
# ## Imports & Settings

# %%
# !pip install ipython-autotime
# !pip install pandas_datareader
# Out:
# Collecting ipython-autotime
#   Downloading ipython_autotime-0.3.1-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: ipython in /opt/conda/lib/python3.7/site-packages (from ipython-autotime) (7.22.0)
# Requirement already satisfied: traitlets>=4.2 in /opt/conda/lib/python3.7/site-packages (from ipython->ipython-autotime) (5.0.5)
# Requirement already satisfied: setuptools>=18.5 in /opt/conda/lib/python3.7/site-packages (from ipython->ipython-autotime) (49.6.0.post20210108)
# Requirement already satisfied: pygments in /opt/conda/lib/python3.7/site-packages (from ipython->ipython-autotime) (2.8.1)
# Requirement already satisfied: backcall in /opt/conda/lib/python3.7/site-packages (from ipython->ipython-autotime) (0.2.0)
# Requirement already satisfied: pickleshare in /opt/conda/lib/python3.7/site-packages (from ipython->ipython-autotime) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from ipython->ipython-autotime) (3.0.18)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.7/site-packages (from ipython->ipython-autotime) (5.0.7)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.7/site-packages (from ipython->ipython-autotime) (0.18.0)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.7/site-packages (from ipython->ipython-autotime) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/conda/lib/python3.7/site-packages (from jedi>=0.16->ipython->ipython-autotime) (0.8.2)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.7/site-packages (from pexpect>4.3->ipython->ipython-autotime) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->ipython-autotime) (0.2.5)
# Requirement already satisfied: ipython-genutils in /opt/conda/lib/python3.7/site-packages (from traitlets>=4.2->ipython->ipython-autotime) (0.2.0)
# Installing collected packages: ipython-autotime
# Successfully installed ipython-autotime-0.3.1
# Collecting pandas_datareader
#   Downloading pandas_datareader-0.9.0-py3-none-any.whl (107 kB)
#      |████████████████████████████████| 107 kB 7.6 MB/s eta 0:00:01
# Requirement already satisfied: requests>=2.19.0 in /opt/conda/lib/python3.7/site-packages (from pandas_datareader) (2.25.1)
# Collecting lxml
#   Downloading lxml-4.6.3-cp37-cp37m-manylinux1_x86_64.whl (5.5 MB)
#      |████████████████████████████████| 5.5 MB 9.7 MB/s eta 0:00:01
# Requirement already satisfied: pandas>=0.23 in /opt/conda/lib/python3.7/site-packages (from pandas_datareader) (1.2.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.7/site-packages (from pandas>=0.23->pandas_datareader) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.7/site-packages (from pandas>=0.23->pandas_datareader) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in /opt/conda/lib/python3.7/site-packages (from pandas>=0.23->pandas_datareader) (1.19.5)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas>=0.23->pandas_datareader) (1.15.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests>=2.19.0->pandas_datareader) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests>=2.19.0->pandas_datareader) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests>=2.19.0->pandas_datareader) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests>=2.19.0->pandas_datareader) (2020.12.5)
# Installing collected packages: lxml, pandas-datareader
# Successfully installed lxml-4.6.3 pandas-datareader-0.9.0

# %%
# hdf failed
#!conda install -y -c anaconda pytables
#!conda install -c ska tables

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from pathlib import Path
import requests
from io import BytesIO
from zipfile import ZipFile, BadZipFile

import numpy as np
import pandas as pd
import pandas_datareader.data as web
from sklearn.datasets import fetch_openml

pd.set_option('display.expand_frame_repr', False)

# %% [markdown]
# ## Set Data Store path

# %% [markdown]
# Modify path if you would like to store the data elsewhere and change the notebooks accordingly

# %%
# %load_ext autotime
### set path
import os
from pathlib import Path
path_home = os.getcwd()
path_home = Path(path_home)
path_data = path_home / 'data'
if not path_data.exists():
    path_data.mkdir()
#path_result = path_home / 'result'
# Out:
# time: 1.69 ms (started: 2021-04-23 14:05:31 +00:00)

# %% [markdown]
# ## Stooq Historical Market Data
# ##### several cells made to one as stooq folder makes notebook freezing
# ##### seems memory intensive

# %%
### Download price data
# 1. Download **price data** for the selected combination of asset class, market and frequency from [the Stooq website](https://stooq.com/db/h/)
# 2. Store the result under `stooq` using the preferred folder structure outlined on the website. It has the structure: `/data/freq/market/asset_class`, such as `/data/daily/us/nasdaq etfs`.

stooq_path = path_home / 'stooq'
if not stooq_path.exists():
    stooq_path.mkdir()

STOOQ_URL = 'https://static.stooq.com/db/h/'

for market in ['jp', 'us']:
    data_url = f'd_{market}_txt.zip'
    response = requests.get(STOOQ_URL + data_url).content
    with ZipFile(BytesIO(response)) as zip_file:
        for i, file in enumerate(zip_file.namelist()):
            if not file.endswith('.txt'):
                continue
            local_file = stooq_path / file
            local_file.parent.mkdir(parents=True, exist_ok=True)
            with local_file.open('wb') as output:
                for line in zip_file.open(file).readlines():
                    output.write(line)

### Add symbols
# Add the corresponding **symbols**, i.e., tickers and names by following the directory tree on the same site. You can also adapt the following code snippet using the appropriate asset code that you find by inspecting the url; this example works for NASDAQ ETFs that have code `g=69`:
# ```python
# df = pd.read_csv('https://stooq.com/db/l/?g=69', sep='        ').apply(lambda x: x.str.strip())
# df.columns = ['ticker', 'name']
# df.drop_duplicates('ticker').to_csv('stooq/data/tickers/us/nasdaq etfs.csv', index=False)
# ```

metadata_dict = {
    ('jp', 'tse etfs'): 34,
    ('jp', 'tse stocks'): 32,
    ('us', 'nasdaq etfs'): 69,
    ('us', 'nasdaq stocks'): 27,
    ('us', 'nyse etfs'): 70,
    ('us', 'nyse stocks'): 28,
    ('us', 'nysemkt stocks'): 26
}

for (market, asset_class), code in metadata_dict.items():
    df = pd.read_csv(f'https://stooq.com/db/l/?g={code}', sep='        ').apply(lambda x: x.str.strip())
    df.columns = ['ticker', 'name']
    df = df.drop_duplicates('ticker').dropna()
    print(market, asset_class, f'# tickers: {df.shape[0]:,.0f}')
    path = stooq_path / 'tickers' / market
    if not path.exists():
        path.mkdir(parents=True)
    df.to_csv(path / f'{asset_class}.csv', index=False)    
    
    
### Store price data
# It removes files that do not have data or do not appear in the corresponding list of symbols.
# The function `get_stooq_prices_and_symbols` loads data assuming the directory structure described above and takes the following arguments:
# - frequency (see Stooq website for options as these may change; default is `daily`
# - market (default: `us`), and 
#- asset class (default: `nasdaq etfs`.

def get_stooq_prices_and_tickers(frequency='daily',
                                 market='us',
                                 asset_class='nasdaq etfs'):
    prices = []
    
    tickers = (pd.read_csv(stooq_path / 'tickers' / market / f'{asset_class}.csv'))

    if frequency in ['5 min', 'hourly']:
        parse_dates = [['date', 'time']]
        date_label = 'date_time'
    else:
        parse_dates = ['date']
        date_label = 'date'
    names = ['ticker', 'freq', 'date', 'time', 
             'open', 'high', 'low', 'close','volume', 'openint']
    
    usecols = ['ticker', 'open', 'high', 'low', 'close', 'volume'] + parse_dates
    path = stooq_path / 'data' / frequency / market / asset_class
    print(path.as_posix())
    files = path.glob('**/*.txt')
    for i, file in enumerate(files, 1):
        if i % 500 == 0:
            print(i)
        if file.stem not in set(tickers.ticker.str.lower()):
            print(file.stem, 'not available')
            file.unlink()
        else:
            try:
                df = (pd.read_csv(
                    file,
                    names=names,
                    usecols=usecols,
                    header=0,
                    parse_dates=parse_dates))
                prices.append(df)
            except pd.errors.EmptyDataError:
                print('\tdata missing', file.stem)
                file.unlink()

    prices = (pd.concat(prices, ignore_index=True)
              .rename(columns=str.lower)
              .set_index(['ticker', date_label])
              .apply(lambda x: pd.to_numeric(x, errors='coerce')))
    return prices, tickers


### We'll be using US equities and ETFs in [Chapter 9](../09_time_series_models) and and Japanese equities in [Chapter 11](../11_decision_trees_random_forests). The following code collects the price data for the period 2000-2019 and stores it with the corresponding symbols in the global `assets.h5` store:
# load some Japanese and all US assets for 2000-2019
markets = {'jp': ['tse stocks'],
           'us': ['nasdaq etfs', 'nasdaq stocks', 'nyse etfs', 'nyse stocks', 'nysemkt stocks']
          }
frequency = 'daily'

idx = pd.IndexSlice
for market, asset_classes in markets.items():
    for asset_class in asset_classes:
        print(f'\n{asset_class}')
        prices, tickers = get_stooq_prices_and_tickers(frequency=frequency, 
                                                       market=market, 
                                                       asset_class=asset_class)
        
        prices = prices.sort_index().loc[idx[:, '2000': '2019'], :]
        names = prices.index.names
        prices = (prices
                  .reset_index()
                  .drop_duplicates()
                  .set_index(names)
                  .sort_index())
        
        print('\nNo. of observations per asset')
        print(prices.groupby('ticker').size().describe())
        key = f'stooq_{market}_{asset_class.replace(" ", "_")}_'
        
        print(prices.info(null_counts=True))
        fn = key + 'prices.csv'
        prices.to_csv(path_data / fn)
        
        print(tickers.info())
        fn = key + 'tickers.csv'
        tickers.to_csv(path_data / fn)

        
### rm stooq dir which make notebook freezed
# !rm -r stooq
# Out:
# jp tse etfs # tickers: 341
# jp tse stocks # tickers: 3,773
# us nasdaq etfs # tickers: 405
# us nasdaq stocks # tickers: 4,187
# us nyse etfs # tickers: 1,822
# us nyse stocks # tickers: 3,397
# us nysemkt stocks # tickers: 292
#
# tse stocks
# /home/jupyter/random_forests/stooq/data/daily/jp/tse stocks
# 500
# 1000
# 1500
# 2000
# 2500
# 3000
# 3500
#
# No. of observations per asset
# count    3623.000000
# mean     2805.231852
# std      1177.353004
# min         1.000000
# 25%      2147.500000
# 50%      3041.000000
# 75%      3621.000000
# max      4905.000000
# dtype: float64
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 10163355 entries, ('1301.JP', Timestamp('2005-03-22 00:00:00')) to ('9997.JP', Timestamp('2019-12-30 00:00:00'))
# Data columns (total 5 columns):
#  #   Column  Non-Null Count     Dtype
# ---  ------  --------------     -----
#  0   open    10163355 non-null  float64
#  1   high    10163355 non-null  float64
#  2   low     10163355 non-null  float64
#  3   close   10163355 non-null  float64
#  4   volume  10163355 non-null  int64
# dtypes: float64(4), int64(1)
# memory usage: 426.8+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3773 entries, 0 to 3772
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ticker  3773 non-null   object
#  1   name    3773 non-null   object
# dtypes: object(2)
# memory usage: 59.1+ KB
# None
#
# nasdaq etfs
# /home/jupyter/random_forests/stooq/data/daily/us/nasdaq etfs
#
# No. of observations per asset
# count     358.000000
# mean     1579.354749
# std      1123.380869
# min         2.000000
# 25%       560.250000
# 50%      1374.500000
# 75%      2339.500000
# max      5031.000000
# dtype: float64
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 565409 entries, ('AAXJ.US', Timestamp('2008-08-15 00:00:00')) to ('YLDE.US', Timestamp('2019-12-27 00:00:00'))
# Data columns (total 5 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   open    565409 non-null  float64
#  1   high    565409 non-null  float64
#  2   low     565409 non-null  float64
#  3   close   565409 non-null  float64
#  4   volume  565409 non-null  int64
# dtypes: float64(4), int64(1)
# memory usage: 23.9+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 405 entries, 0 to 404
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ticker  405 non-null    object
#  1   name    405 non-null    object
# dtypes: object(2)
# memory usage: 6.5+ KB
# None
#
# nasdaq stocks
# /home/jupyter/random_forests/stooq/data/daily/us/nasdaq stocks
# 500
# 1000
# 1500
# 2000
# 2500
# 3000
# 3500
# 4000
#
# No. of observations per asset
# count    2854.000000
# mean     2108.654870
# std      1508.555995
# min         1.000000
# 25%       575.250000
# 50%      1906.000000
# 75%      3734.000000
# max      5031.000000
# dtype: float64
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 6018101 entries, ('AACG.US', Timestamp('2008-01-28 00:00:00')) to ('ZYXI.US', Timestamp('2019-12-31 00:00:00'))
# Data columns (total 5 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   open    6018101 non-null  float64
#  1   high    6018101 non-null  float64
#  2   low     6018101 non-null  float64
#  3   close   6018101 non-null  float64
#  4   volume  6018101 non-null  int64
# dtypes: float64(4), int64(1)
# memory usage: 252.8+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4187 entries, 0 to 4186
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ticker  4187 non-null   object
#  1   name    4187 non-null   object
# dtypes: object(2)
# memory usage: 65.5+ KB
# None
#
# nyse etfs
# /home/jupyter/random_forests/stooq/data/daily/us/nyse etfs
# tmat.us not available
# fsmo.us not available
# bgld.us not available
# fpro.us not available
# fmag.us not available
# 500
# fgro.us not available
# 1000
# febz.us not available
# marz.us not available
# 1500
# minn.us not available
# bufd.us not available
#
# No. of observations per asset
# count    1550.000000
# mean     1763.168387
# std      1244.899444
# min         1.000000
# 25%       552.250000
# 50%      1603.000000
# 75%      3002.250000
# max      3738.000000
# dtype: float64
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 2732911 entries, ('AAAU.US', Timestamp('2018-08-15 00:00:00')) to ('ZSL.US', Timestamp('2019-12-31 00:00:00'))
# Data columns (total 5 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   open    2732911 non-null  float64
#  1   high    2732911 non-null  float64
#  2   low     2732911 non-null  float64
#  3   close   2732911 non-null  float64
#  4   volume  2732911 non-null  int64
# dtypes: float64(4), int64(1)
# memory usage: 114.9+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1822 entries, 0 to 1821
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ticker  1822 non-null   object
#  1   name    1822 non-null   object
# dtypes: object(2)
# memory usage: 28.6+ KB
# None
#
# nyse stocks
# /home/jupyter/random_forests/stooq/data/daily/us/nyse stocks
# cpsr-u.us not available
# faii-ws.us not available
# fpac-ws.us not available
# isos-u.us not available
# ccx-ws.us not available
# cubi_c.us not available
# cptk-u.us not available
# csta-ws.us not available
# cas-ws.us not available
# boas-ws.us not available
# clim-u.us not available
# cbah-ws.us not available
# hhla-u.us not available
# ajax-u.us not available
# foa-ws.us not available
# insw_a.us not available
# dfns-ws.us not available
# glog_a.us not available
# apsg-u.us not available
# fuse-u.us not available
# codi_c.us not available
# htpa-ws.us not available
# ipod-u.us not available
# bgsx-u.us not available
# ccvi-u.us not available
# boac-ws.us not available
# ccac-u.us not available
# hzon-ws.us not available
# iaca-u.us not available
# eqd-ws.us not available
# dwin-u.us not available
# aspl-ws.us not available
# fst-ws.us not available
# iaca-ws.us not available
# empw-ws.us not available
# goac-ws.us not available
# cvii-u.us not available
# ipv-ws.us not available
# iiac-ws.us not available
# gsah-u.us not available
# gnpk-ws.us not available
# aone-ws.us not available
# ctac-ws.us not available
# fmac-ws.us not available
# cnd-ws.us not available
# faca-ws.us not available
# dmyd-ws.us not available
# fsnb-u.us not available
# asai-w.us not available
# faca-u.us not available
# claa-u.us not available
# cap-ws.us not available
# clim-ws.us not available
# bft-ws.us not available
# boac-u.us not available
# asaq-u.us not available
# clny_g.us not available
# etwo-ws.us not available
# cubi_f.us not available
# atco_e.us not available
# clas-ws.us not available
# avtr_a.us not available
# clny_h.us not available
# atmr-u.us not available
# banc_e.us not available
# clii-ws.us not available
# jema.us not available
# 500
# fsnb-ws.us not available
# iacb-u.us not available
# hpx-ws.us not available
# alus-ws.us not available
# atco_h.us not available
# alus-u.us not available
# htpa-u.us not available
# aus-ws.us not available
# blua-u.us not available
# gik-ws.us not available
# flme-ws.us not available
# codi_b.us not available
# aaic_b.us not available
# cpsr-ws.us not available
# fvt-ws.us not available
# hzon-u.us not available
# gsah-ws.us not available
# aeva-ws.us not available
# crhc-ws.us not available
# atac-u.us not available
# crhc-u.us not available
# eqha-ws.us not available
# ccac-ws.us not available
# dgnr-u.us not available
# cptk-ws.us not available
# anac-u.us not available
# csan-w.us not available
# anac-ws.us not available
# iber-ws.us not available
# cubi_d.us not available
# atac-ws.us not available
# empw-u.us not available
# agac-ws.us not available
# fsr-ws.us not available
# adex-u.us not available
# glop_a.us not available
# glop_c.us not available
# dmyd-u.us not available
# frxb-u.us not available
# fmac-u.us not available
# ampi-u.us not available
# faii-u.us not available
# aone-u.us not available
# dlng_b.us not available
# gutr-w.us not available
# chaa-ws.us not available
# chmi_b.us not available
# enpc-u.us not available
# dnz-ws.us not available
# ipvf-u.us not available
# hzac-u.us not available
# cwen-a.us not available
# celg-r.us not available
# asaq-ws.us not available
# dapr.us not available
# apgb-ws.us not available
# cubi_e.us not available
# fmar.us not available
# argo_a.us not available
# epwr-u.us not available
# ipof-ws.us not available
# fcax-u.us not available
# iacb-ws.us not available
# aaqc-u.us not available
# ctos-ws.us not available
# fpac-u.us not available
# 1000
# acii-ws.us not available
# dwin-ws.us not available
# dmyi-ws.us not available
# goac-u.us not available
# ajax-ws.us not available
# hfro_a.us not available
# gfx-ws.us not available
# apsg-ws.us not available
# ipof-u.us not available
# cmre_b.us not available
# gleo-ws.us not available
# fact-ws.us not available
# dmar.us not available
# dmyq-u.us not available
# ivan-u.us not available
# altg-ws.us not available
# gix-ws.us not available
# codi_a.us not available
# acnd-ws.us not available
# ftai_c.us not available
# atco_i.us not available
# avan-u.us not available
# dlng_a.us not available
# ares_a.us not available
# clas-u.us not available
# ftev-u.us not available
# iipr_a.us not available
# cbah-u.us not available
# hugs-ws.us not available
# alin_a.us not available
# gsqd-u.us not available
# aac-ws.us not available
# fgna-u.us not available
# hims-ws.us not available
# aspl-u.us not available
# acii-u.us not available
# cmre_c.us not available
# ftai_a.us not available
# cpuh-ws.us not available
# alin_e.us not available
# higa-ws.us not available
# ipoe-u.us not available
# gsqd-ws.us not available
# fapr.us not available
# cmre_d.us not available
# geni-ws.us not available
# cve-ws.us not available
# bite-u.us not available
# dfns-u.us not available
# dmyi-u.us not available
# cla-ws.us not available
# enpc-ws.us not available
# fviv-u.us not available
# boas-u.us not available
# chpt-ws.us not available
# iiac-u.us not available
# higa-u.us not available
# cmre_e.us not available
# asz-ws.us not available
# epwr-ws.us not available
# flme-u.us not available
# 1500
# chaa-u.us not available
# hmlp_a.us not available
# eqha-u.us not available
# acic-u.us not available
# impx-u.us not available
# ally_a.us not available
# avan-ws.us not available
# csta-u.us not available
# cpuh-u.us not available
# blua-ws.us not available
# arkx.us not available
# fcax-ws.us not available
# hugs-u.us not available
# apgb-u.us not available
# banc_d.us not available
# iber-u.us not available
# acic-ws.us not available
# atmr-ws.us not available
# fuse-ws.us not available
# ccv-ws.us not available
# agac-u.us not available
# alin_b.us not available
# ivan-ws.us not available
# ccvi-ws.us not available
# cru-ws.us not available
# ipoe-ws.us not available
# frx-ws.us not available
# altg_a.us not available
# dgnr-ws.us not available
# ipva-u.us not available
# ata-ws.us not available
# glop_b.us not available
# ipod-ws.us not available
# corr_a.us not available
# athn-u.us not available
# fgna-ws.us not available
# atco_d.us not available
# chmi_a.us not available
# deh-ws.us not available
# cvii-ws.us not available
# clny_j.us not available
# dms-ws.us not available
# clii-u.us not available
# acnd-u.us not available
# fact-u.us not available
# aaic_c.us not available
# dnmr-ws.us not available
# jih-ws.us not available
# bsn-ws.us not available
# bite-ws.us not available
# gnpk-u.us not available
# bfly-ws.us not available
# cciv-ws.us not available
# cciv-u.us not available
# gleo-u.us not available
# ftai_b.us not available
# clny_i.us not available
# ataq-u.us not available
# aptv_a.us not available
# gmre_a.us not available
# ctac-u.us not available
# ambc-ws.us not available
# imfl.us not available
# hzac-ws.us not available
# hhla-ws.us not available
# adex-ws.us not available
# gapa-u.us not available
# impx-ws.us not available
# atco_g.us not available
# 2000
# rbac-u.us not available
# tinv-u.us not available
# trtn_d.us not available
# rexr_c.us not available
# splp_a.us not available
# pntm-u.us not available
# twnd-ws.us not available
# prif_f.us not available
# xpoa-u.us not available
# vpcc-u.us not available
# qmar.us not available
# rtpz-u.us not available
# rsi-ws.us not available
# tdw-ws-a.us not available
# mdh-ws.us not available
# mamb.us not available
# rmo-ws.us not available
# piai-u.us not available
# kcac-u.us not available
# lokm-u.us not available
# rtp-ws.us not available
# mbac-u.us not available
# nga-ws.us not available
# rtpz-ws.us not available
# treb-u.us not available
# warr-ws.us not available
# rice-ws.us not available
# slac-ws.us not available
# spfr-u.us not available
# leap-ws.us not available
# vygg-u.us not available
# nstb-ws.us not available
# sbe-ws.us not available
# stag_c.us not available
# nstb-u.us not available
# spgs-ws.us not available
# treb-ws.us not available
# soac-u.us not available
# lhc-ws.us not available
# sbg-ws.us not available
# xflt_a.us not available
# nsco-ws.us not available
# soac-ws.us not available
# uwmc-ws.us not available
# 2500
# mitt_c.us not available
# nuvb-ws.us not available
# macc-u.us not available
# taca-ws.us not available
# jws-ws.us not available
# tinv-ws.us not available
# kwac-u.us not available
# pipp-ws.us not available
# wpcb-u.us not available
# nstd-u.us not available
# sitc_k.us not available
# mitt_a.us not available
# picc-u.us not available
# scpe-u.us not available
# scvx-u.us not available
# seah-ws.us not available
# piai-ws.us not available
# liii-u.us not available
# rexr_b.us not available
# ross-u.us not available
# prif_c.us not available
# stic-ws.us not available
# nycb_a.us not available
# schw_c.us not available
# picc-ws.us not available
# qfta-ws.us not available
# tspq-u.us not available
# lgvw-ws.us not available
# sftw-u.us not available
# sklz-ws.us not available
# prpb-u.us not available
# tpgy-ws.us not available
# sprq-ws.us not available
# rice-u.us not available
# lnfa-ws.us not available
# trtn_a.us not available
# oacb-ws.us not available
# qfta-u.us not available
# pdac-u.us not available
# prif_b.us not available
# snii-u.us not available
# mit-ws.us not available
# stpc-ws.us not available
# sbii-u.us not available
# nref_a.us not available
# prpc-ws.us not available
# nycb_u.us not available
# taca-u.us not available
# nfh-ws.us not available
# 3000
# mitt_b.us not available
# voya_b.us not available
# motv-u.us not available
# qcon.us not available
# prif_d.us not available
# trca-u.us not available
# prif_g.us not available
# schw_j.us not available
# snpr-ws.us not available
# twnt-u.us not available
# warr-u.us not available
# vgac-ws.us not available
# kahc-u.us not available
# tdw-ws-b.us not available
# prpc-u.us not available
# yac-ws.us not available
# liii-ws.us not available
# oxy-ws.us not available
# spgs-u.us not available
# schw_d.us not available
# spfr-ws.us not available
# mpro.us not available
# psfe-ws.us not available
# star_i.us not available
# xpoa-ws.us not available
# pipp-u.us not available
# qpff.us not available
# jwsm-u.us not available
# stpk-ws.us not available
# pmvc-ws.us not available
# motv-ws.us not available
# vgii-u.us not available
# twnd-u.us not available
# vst-ws-a.us not available
# oibr-c.us not available
# pntm-ws.us not available
# nsh-ws.us not available
# oust-ws.us not available
# scvx-ws.us not available
# tpgy-u.us not available
# spaq-u.us not available
# pana-u.us not available
# sftw-ws.us not available
# pcpc-ws.us not available
# slac-u.us not available
# rbac-ws.us not available
# psth-ws.us not available
# leap-u.us not available
# pcpc-u.us not available
# sitc_a.us not available
# nxu-ws.us not available
# prif_e.us not available
# lokb-u.us not available
# rpla-ws.us not available
# oacb-u.us not available
# spnv-u.us not available
# rpla-u.us not available
# stpk-u.us not available
# pace-ws.us not available
# rexr_a.us not available
# sprq-u.us not available
# pace-u.us not available
# 3500
# snpr-u.us not available
# nstc-u.us not available
# seah-u.us not available
# ymar.us not available
# scpe-ws.us not available
# wpca-u.us not available
# kcac-ws.us not available
# star_g.us not available
# twni-ws.us not available
# prpb-ws.us not available
# tmac-ws.us not available
# wpf-ws.us not available
# jwsm-ws.us not available
# stic-u.us not available
# vgac-u.us not available
# twni-u.us not available
# sqmr-w.us not available
# spnv-ws.us not available
# lokb-ws.us not available
# pcpl-u.us not available
# pmvc-u.us not available
# swbk-ws.us not available
# kwac-ws.us not available
# tlga-u.us not available
# spaq-ws.us not available
# trtn_c.us not available
# oca-ws.us not available
# pdot-u.us not available
# stre-u.us not available
# ngab-ws.us not available
# stpc-u.us not available
# pdac-ws.us not available
# star_d.us not available
# ngab-u.us not available
# mpln-ws.us not available
# lnfa-u.us not available
# rot-ws.us not available
# swbk-u.us not available
# vygg-ws.us not available
# prif_a.us not available
# tlga-ws.us not available
# tmac-u.us not available
# rkta-u.us not available
# mbcc.us not available
# trtn_b.us not available
#
# No. of observations per asset
# count    2864.000000
# mean     2481.433659
# std      1550.766941
# min         1.000000
# 25%       906.000000
# 50%      2689.500000
# 75%      3737.000000
# max      5031.000000
# dtype: float64
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 7106826 entries, ('A.US', Timestamp('2000-01-03 00:00:00')) to ('ZYME.US', Timestamp('2019-12-31 00:00:00'))
# Data columns (total 5 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   open    7106826 non-null  float64
#  1   high    7106826 non-null  float64
#  2   low     7106826 non-null  float64
#  3   close   7106826 non-null  float64
#  4   volume  7106826 non-null  int64
# dtypes: float64(4), int64(1)
# memory usage: 298.5+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3397 entries, 0 to 3396
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ticker  3397 non-null   object
#  1   name    3397 non-null   object
# dtypes: object(2)
# memory usage: 53.2+ KB
# None
#
# nysemkt stocks
# /home/jupyter/random_forests/stooq/data/daily/us/nysemkt stocks
# chaq-u.us not available
# nba-ws.us not available
# nspr-ws.us not available
# phge-ws.us not available
# chfw-u.us not available
# nspr-ws-b.us not available
# bmtx-ws.us not available
# groy-ws.us not available
# ycbd_a.us not available
# vhaq-u.us not available
# plym_a.us not available
# talo-ws.us not available
# adra-u.us not available
# adra-ws.us not available
# uuuu-ws.us not available
# ptk-ws.us not available
# vhaq-ws.us not available
# klr-ws.us not available
# chaq-ws.us not available
# vhaq-r.us not available
# tdw-ws.us not available
# lgl-ws.us not available
# chfw-ws.us not available
# brmk-ws.us not available
#
# No. of observations per asset
# count     268.000000
# mean     2616.003731
# std      1294.055448
# min         4.000000
# 25%      1505.000000
# 50%      3334.000000
# 75%      3726.250000
# max      5029.000000
# dtype: float64
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 701089 entries, ('AAMC.US', Timestamp('2012-12-13 00:00:00')) to ('ZOM.US', Timestamp('2019-12-31 00:00:00'))
# Data columns (total 5 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   open    701089 non-null  float64
#  1   high    701089 non-null  float64
#  2   low     701089 non-null  float64
#  3   close   701089 non-null  float64
#  4   volume  701089 non-null  int64
# dtypes: float64(4), int64(1)
# memory usage: 29.6+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292 entries, 0 to 291
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ticker  292 non-null    object
#  1   name    292 non-null    object
# dtypes: object(2)
# memory usage: 4.7+ KB
# None
# time: 8min 1s (started: 2021-04-23 14:05:32 +00:00)

# %%
# !zip data_stooq.zip data/*
# Out:
#   adding: data/stooq_jp_tse_stocks_prices.csv (deflated 74%)
#   adding: data/stooq_jp_tse_stocks_tickers.csv (deflated 58%)
#   adding: data/stooq_us_nasdaq_etfs_prices.csv (deflated 71%)
#   adding: data/stooq_us_nasdaq_etfs_tickers.csv (deflated 70%)
#   adding: data/stooq_us_nasdaq_stocks_prices.csv (deflated 70%)
#   adding: data/stooq_us_nasdaq_stocks_tickers.csv (deflated 63%)
#   adding: data/stooq_us_nyse_etfs_prices.csv (deflated 70%)
#   adding: data/stooq_us_nyse_etfs_tickers.csv (deflated 71%)
#   adding: data/stooq_us_nyse_stocks_prices.csv (deflated 69%)
#   adding: data/stooq_us_nyse_stocks_tickers.csv (deflated 62%)
#   adding: data/stooq_us_nysemkt_stocks_prices.csv (deflated 73%)
#   adding: data/stooq_us_nysemkt_stocks_tickers.csv (deflated 55%)
# time: 1min 53s (started: 2021-04-23 14:13:33 +00:00)

# %%
# !gsutil cp data_stooq.zip gs://finance_data_bucket
# Out:
# Copying file://data_stooq.zip [Content-Type=application/zip]...
# ==> NOTE: You are uploading one or more large file(s), which would run
# significantly faster if you enable parallel composite uploads. This
# feature can be enabled by editing the
# "parallel_composite_upload_threshold" value in your .boto
# configuration file. However, note that if you do this large files will
# be uploaded as `composite objects
# <https://cloud.google.com/storage/docs/composite-objects>`_,which
# means that any user who downloads such objects will need to have a
# compiled crcmod installed (see "gsutil help crcmod"). This is because
# without a compiled crcmod, computing checksums on composite objects is
# so slow that gsutil disables downloads of composite objects.
#
# / [1 files][386.2 MiB/386.2 MiB]
# Operation completed over 1 objects/386.2 MiB.
# time: 5.95 s (started: 2021-04-23 14:15:27 +00:00)
